# %%
#import relevant modules
import mysql.connector as sql 
import pandas as pd
#open connection
conn = sql.connect( 
	host='localhost', 
  	database='whodatabase', 
  	user='root', 
  	password= "Zeethwala#98")
#prepare cursor object
mycursor = conn.cursor()
#see data in a dataframe
df = pd.read_sql('SELECT * from whocovidstats', conn)
df.head()

# disconnect from server
conn.close()

# %%
import mysql.connector as sql 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

conn = sql.connect( 
	host='localhost', 
  	database='whodatabase', 
  	user='root', 
  	password= "Zeethwala#98")

mycursor = conn.cursor()

df = pd.read_sql('SELECT * from whocovidstats', conn)
df.head()

#Compare TotalDeath according to dates
df.groupby(['Date_epicrv']).mean()['TotalDeath'].plot(kind='bar', figsize=(20,12))
plt.xticks(rotation=90)
plt.ylabel('TotalDeath')
plt.title('WHO Covid-19 Statistics')
plt.show()

# disconnect from server
conn.close()

# %%
import mysql.connector as sql 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
conn = sql.connect( 
	host='localhost', 
  	database='whodatabase', 
  	user='root', 
  	password= "Zeethwala#98")

mycursor = conn.cursor()

df = pd.read_sql('SELECT * from whocovidstats', conn)
df.head()

df.groupby(['Date_epicrv']).mean()['TotalCase'].plot(kind='bar', figsize=(20,12))
plt.xticks(rotation=90)
plt.ylabel('TotalCase')
plt.title('WHO Covid-19 Statistics')

#show data
plt.show()

# disconnect from server
conn.close()

# %%
import mysql.connector as sql 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

conn = sql.connect( 
	host='localhost', 
  	database='whodatabase', 
  	user='root', 
  	password= "Zeethwala#98")

mycursor = conn.cursor()

df = pd.read_sql('SELECT * from whocovidstats', conn)
df.head()

df.groupby(['Date_epicrv']).mean()['NewCase'].plot(kind='line', figsize=(20,12))
plt.xticks(rotation=90)
plt.ylabel('NewCase')
plt.title('WHO Covid-19 Statistics')

plt.show()

# disconnect from server
conn.close()

# %%
import mysql.connector as sql 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

conn = sql.connect( 
	host='localhost', 
  	database='whodatabase', 
  	user='root', 
  	password= "Zeethwala#98")

mycursor = conn.cursor()

df = pd.read_sql('SELECT * from whocovidstats', conn)
df.head()

df.groupby(['NewCase']).mean()['NewDeath'].plot(kind='line', figsize=(20,12))
plt.xticks(rotation=90)
plt.ylabel('NewDeath')
plt.title('WHO Covid-19 Statistics')

plt.show()

# disconnect from server
conn.close()

# %%
import mysql.connector as sql 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

conn = sql.connect( 
	host='localhost', 
  	database='whodatabase', 
  	user='root', 
  	password= "Zeethwala#98")

mycursor = conn.cursor()

df = pd.read_sql('SELECT * from whocovidstats', conn)
df.head()

# scatter plot between income and age 
plt.figure(figsize=(18, 10))

plt.scatter(df['NewCase'], df['TotalCase']) 

plt.ylabel('TotalCase', color = 'red')
plt.xlabel('NewCase', color = 'blue')
plt.title('WHO Covid-19 Statistics')

plt.show() 
  

# disconnect from server
conn.close()

# %%
import mysql.connector as sql 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

conn = sql.connect( 
	host='localhost', 
  	database='whodatabase', 
  	user='root', 
  	password= "Zeethwala#98")

mycursor = conn.cursor()

df = pd.read_sql('SELECT * from whocovidstats', conn)
df.head()

# scatter plot between income and age 
plt.figure(figsize=(18, 10))

plt.scatter(df['NewDeath'], df['TotalDeath']) 

plt.ylabel('TotalDeath', color = "red")
plt.xlabel('NewDeath')
plt.title('WHO Covid-19 Statistics', color = "blue")

plt.show() 
  

# disconnect from server
conn.close()
